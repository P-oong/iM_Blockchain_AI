# %%
# =========================
# 1. 기본 라이브러리
# =========================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)
pd.set_option("display.float_format", "{:,.2f}".format)


# =========================
# 2. 데이터 불러오기
# =========================
DATA_PATH = "../data/synthetic/business_crisis_cohort_v5.csv"

df = pd.read_csv(DATA_PATH)

print("shape:", df.shape)
display(df.head())

# %%
# 컬럼 / 데이터 타입 / 결측치 확인
df.info()

display(
    pd.DataFrame({
        "dtype": df.dtypes,
        "nunique": df.nunique(),
        "missing": df.isna().sum(),
        "missing_pct": df.isna().mean() * 100
    })
)
